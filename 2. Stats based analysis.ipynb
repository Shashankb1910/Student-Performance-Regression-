# %% [markdown]
# # Stats Analysis

# %% [markdown]
# - Exploring Features of the dataset
# - Hypothesis Testing
# - Checking for Normal Distribution using Transformations

# %% [markdown]
# ###  Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy import stats
import scipy.stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data/cleaned.csv')

# %% [markdown]
# #### Show Top 5 Records

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# 4          229  76.333333

# %% [markdown]
# ### 2 .Hypothesis Testing
# #### 2.1 Checking correlation

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df_encoded = pd.get_dummies(df)

# Convert all columns to numeric data types (ignore errors for non-numeric values)
df_numeric = df_encoded.apply(pd.to_numeric, errors='coerce')

# Drop any rows with NaN values
df_numeric.dropna(inplace=True)

# Compute correlation matrix
correlation_matrix = df_numeric.corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#                                                 math score  reading score  \
# math score                                        1.000000       0.817580
# reading score                                     0.817580       1.000000
# writing score                                     0.802642       0.954598
# total score                                       0.918746       0.970331
# average                                           0.918746       0.970331
# gender_female                                    -0.167982       0.244313
# gender_male                                       0.167982      -0.244313
# race/ethnicity_group A                           -0.091977      -0.096274
# race/ethnicity_group B                           -0.084250      -0.060283
# race/ethnicity_group C                           -0.073387      -0.003074
# race/ethnicity_group D                            0.050071       0.035177
# race/ethnicity_group E                            0.205855       0.106712
# parental level of education_associate's degree    0.063228       0.064386
# parental level of education_bachelor's degree     0.079664       0.096024
# parental level of education_high school          -0.128725      -0.151068
# parental level of education_master's degree       0.060417       0.106452
# parental level of education_some college          0.037056       0.010782
# parental level of education_some high school     -0.079852      -0.071369
# lunch_free/reduced                               -0.350877      -0.229560
# lunch_standard                                    0.350877       0.229560
# test preparation course_completed                 0.177702       0.241780
# test preparation course_none                     -0.177702      -0.241780
#
#                                                 writing score  total score  \
# math score                                           0.802642     0.918746
# reading score                                        0.954598     0.970331
# writing score                                        1.000000     0.965667
# total score                                          0.965667     1.000000
# average                                              0.965667     1.000000
# gender_female                                        0.301225     0.130861
# gender_male                                         -0.301225    -0.130861
# race/ethnicity_group A                              -0.110714    -0.104803
# race/ethnicity_group B                              -0.078254    -0.078247
# race/ethnicity_group C                              -0.010203    -0.030691
# race/ethnicity_group D                               0.082032     0.058902
# race/ethnicity_group E                               0.089077     0.141050
# parental level of education_associate's degree       0.064799     0.067414
# parental level of education_bachelor's degree        0.128297     0.106599
# parental level of education_high school             -0.182211    -0.161936
# parental level of education_master's degree          0.125693     0.102411
# parental level of education_some college             0.027989     0.026761
# parental level of education_some high school        -0.097326    -0.087247
# lunch_free/reduced                                  -0.245769    -0.290064
# lunch_standard                                       0.245769     0.290064
# test preparation course_completed                    0.312946     0.256710
# test preparation course_none                        -0.312946    -0.256710
#
#                                                  average  gender_female  \
# math score                                      0.918746      -0.167982
# reading score                                   0.970331       0.244313
# writing score                                   0.965667       0.301225
# total score                                     1.000000       0.130861
# average                                         1.000000       0.130861
# gender_female                                   0.130861       1.000000
# gender_male                                    -0.130861      -1.000000
# race/ethnicity_group A                         -0.104803      -0.071001
# race/ethnicity_group B                         -0.078247       0.028466
# race/ethnicity_group C                         -0.030691       0.063368
# race/ethnicity_group D                          0.058902      -0.030566
# race/ethnicity_group E                          0.141050      -0.020302
# parental level of education_associate's degree  0.067414       0.004835
# parental level of education_bachelor's degree   0.106599       0.011638
# parental level of education_high school        -0.161936      -0.037952
# parental level of education_master's degree     0.102411       0.046188
# parental level of education_some college        0.026761       0.004460
# parental level of education_some high school   -0.087247      -0.008990
# lunch_free/reduced                             -0.290064       0.021372
# lunch_standard                                  0.290064      -0.021372
# test preparation course_completed               0.256710      -0.006028
# test preparation course_none                   -0.256710       0.006028
#
#                                                 gender_male  \
# math score                                         0.167982
# reading score                                     -0.244313
# writing score                                     -0.301225
# total score                                       -0.130861
# average                                           -0.130861
# gender_female                                     -1.000000
# gender_male                                        1.000000
# race/ethnicity_group A                             0.071001
# race/ethnicity_group B                            -0.028466
# race/ethnicity_group C                            -0.063368
# race/ethnicity_group D                             0.030566
# race/ethnicity_group E                             0.020302
# parental level of education_associate's degree    -0.004835
# parental level of education_bachelor's degree     -0.011638
# parental level of education_high school            0.037952
# parental level of education_master's degree       -0.046188
# parental level of education_some college          -0.004460
# parental level of education_some high school       0.008990
# lunch_free/reduced                                -0.021372
# lunch_standard                                     0.021372
# test preparation course_completed                  0.006028
# test preparation course_none                      -0.006028
#
#                                                 race/ethnicity_group A  \
# math score                                                   -0.091977
# reading score                                                -0.096274
# writing score                                                -0.110714
# total score                                                  -0.104803
# average                                                      -0.104803
# gender_female                                                -0.071001
# gender_male                                                   0.071001
# race/ethnicity_group A                                        1.000000
# race/ethnicity_group B                                       -0.151381
# race/ethnicity_group C                                       -0.213923
# race/ethnicity_group D                                       -0.186234
# race/ethnicity_group E                                       -0.126110
# parental level of education_associate's degree               -0.048658
# parental level of education_bachelor's degree                 0.016307
# parental level of education_high school                       0.004919
# parental level of education_master's degree                  -0.033551
# parental level of education_some college                     -0.017751
# parental level of education_some high school                  0.073921
# lunch_free/reduced                                            0.032329
# lunch_standard                                               -0.032329
# test preparation course_completed                            -0.006315
# test preparation course_none                                  0.006315
#
#                                                 race/ethnicity_group B  \
# math score                                                   -0.084250
# reading score                                                -0.060283
# writing score                                                -0.078254
# total score                                                  -0.078247
# average                                                      -0.078247
# gender_female                                                 0.028466
# gender_male                                                  -0.028466
# race/ethnicity_group A                                       -0.151381
# race/ethnicity_group B                                        1.000000
# race/ethnicity_group C                                       -0.331479
# race/ethnicity_group D                                       -0.288574
# race/ethnicity_group E                                       -0.195411
# parental level of education_associate's degree               -0.007238
# parental level of education_bachelor's degree                -0.019121
# parental level of education_high school                       0.069093
# parental level of education_master's degree                  -0.056363
# parental level of education_some college                     -0.036203
# parental level of education_some high school                  0.026531
# lunch_free/reduced                                            0.008257
# lunch_standard                                               -0.008257
# test preparation course_completed                            -0.000106
# test preparation course_none                                  0.000106
#
#                                                 race/ethnicity_group C  ...  \
# math score                                                   -0.073387  ...
# reading score                                                -0.003074  ...
# writing score                                                -0.010203  ...
# total score                                                  -0.030691  ...
# average                                                      -0.030691  ...
# gender_female                                                 0.063368  ...
# gender_male                                                  -0.063368  ...
# race/ethnicity_group A                                       -0.213923  ...
# race/ethnicity_group B                                       -0.331479  ...
# race/ethnicity_group C                                        1.000000  ...
# race/ethnicity_group D                                       -0.407797  ...
# race/ethnicity_group E                                       -0.276145  ...
# parental level of education_associate's degree                0.037077  ...
# parental level of education_bachelor's degree                 0.015682  ...
# parental level of education_high school                       0.007977  ...
# parental level of education_master's degree                   0.001630  ...
# parental level of education_some college                     -0.015872  ...
# parental level of education_some high school                 -0.045339  ...
# lunch_free/reduced                                            0.003385  ...
# lunch_standard                                               -0.003385  ...
# test preparation course_completed                             0.012522  ...
# test preparation course_none                                 -0.012522  ...
#
#                                                 parental level of education_associate's degree  \
# math score                                                                            0.063228
# reading score                                                                         0.064386
# writing score                                                                         0.064799
# total score                                                                           0.067414
# average                                                                               0.067414
# gender_female                                                                         0.004835
# gender_male                                                                          -0.004835
# race/ethnicity_group A                                                               -0.048658
# race/ethnicity_group B                                                               -0.007238
# race/ethnicity_group C                                                                0.037077
# race/ethnicity_group D                                                               -0.044674
# race/ethnicity_group E                                                                0.054922
# parental level of education_associate's degree                                        1.000000
# parental level of education_bachelor's degree                                        -0.195386
# parental level of education_high school                                              -0.263746
# parental level of education_master's degree                                          -0.133757
# parental level of education_some college                                             -0.288649
# parental level of education_some high school                                         -0.249426
# lunch_free/reduced                                                                   -0.009102
# lunch_standard                                                                        0.009102
# test preparation course_completed                                                     0.012668
# test preparation course_none                                                         -0.012668
#
#                                                 parental level of education_bachelor's degree  \
# math score                                                                           0.079664
# reading score                                                                        0.096024
# writing score                                                                        0.128297
# total score                                                                          0.106599
# average                                                                              0.106599
# gender_female                                                                        0.011638
# gender_male                                                                         -0.011638
# race/ethnicity_group A                                                               0.016307
# race/ethnicity_group B                                                              -0.019121
# race/ethnicity_group C                                                               0.015682
# race/ethnicity_group D                                                              -0.020556
# race/ethnicity_group E                                                               0.013221
# parental level of education_associate's degree                                      -0.195386
# parental level of education_bachelor's degree                                        1.000000
# parental level of education_high school                                             -0.180595
# parental level of education_master's degree                                         -0.091588
# parental level of education_some college                                            -0.197647
# parental level of education_some high school                                        -0.170790
# lunch_free/reduced                                                                   0.013668
# lunch_standard                                                                      -0.013668
# test preparation course_completed                                                    0.024285
# test preparation course_none                                                        -0.024285
#
#                                                 parental level of education_high school  \
# math score                                                                    -0.128725
# reading score                                                                 -0.151068
# writing score                                                                 -0.182211
# total score                                                                   -0.161936
# average                                                                       -0.161936
# gender_female                                                                 -0.037952
# gender_male                                                                    0.037952
# race/ethnicity_group A                                                         0.004919
# race/ethnicity_group B                                                         0.069093
# race/ethnicity_group C                                                         0.007977
# race/ethnicity_group D                                                        -0.042118
# race/ethnicity_group E                                                        -0.039494
# parental level of education_associate's degree                                -0.263746
# parental level of education_bachelor's degree                                 -0.180595
# parental level of education_high school                                        1.000000
# parental level of education_master's degree                                   -0.123632
# parental level of education_some college                                      -0.266799
# parental level of education_some high school                                  -0.230545
# lunch_free/reduced                                                             0.002211
# lunch_standard                                                                -0.002211
# test preparation course_completed                                             -0.074446
# test preparation course_none                                                   0.074446
#
#                                                 parental level of education_master's degree  \
# math score                                                                         0.060417
# reading score                                                                      0.106452
# writing score                                                                      0.125693
# total score                                                                        0.102411
# average                                                                            0.102411
# gender_female                                                                      0.046188
# gender_male                                                                       -0.046188
# race/ethnicity_group A                                                            -0.033551
# race/ethnicity_group B                                                            -0.056363
# race/ethnicity_group C                                                             0.001630
# race/ethnicity_group D                                                             0.072793
# race/ethnicity_group E                                                            -0.003180
# parental level of education_associate's degree                                    -0.133757
# parental level of education_bachelor's degree                                     -0.091588
# parental level of education_high school                                           -0.123632
# parental level of education_master's degree                                        1.000000
# parental level of education_some college                                          -0.135305
# parental level of education_some high school                                      -0.116919
# lunch_free/reduced                                                                 0.027095
# lunch_standard                                                                    -0.027095
# test preparation course_completed                                                 -0.009933
# test preparation course_none                                                       0.009933
#
#                                                 parental level of education_some college  \
# math score                                                                      0.037056
# reading score                                                                   0.010782
# writing score                                                                   0.027989
# total score                                                                     0.026761
# average                                                                         0.026761
# gender_female                                                                   0.004460
# gender_male                                                                    -0.004460
# race/ethnicity_group A                                                         -0.017751
# race/ethnicity_group B                                                         -0.036203
# race/ethnicity_group C                                                         -0.015872
# race/ethnicity_group D                                                          0.042347
# race/ethnicity_group E                                                          0.023153
# parental level of education_associate's degree                                 -0.288649
# parental level of education_bachelor's degree                                  -0.197647
# parental level of education_high school                                        -0.266799
# parental level of education_master's degree                                    -0.135305
# parental level of education_some college                                        1.000000
# parental level of education_some high school                                   -0.252312
# lunch_free/reduced                                                             -0.006146
# lunch_standard                                                                  0.006146
# test preparation course_completed                                              -0.019490
# test preparation course_none                                                    0.019490
#
#                                                 parental level of education_some high school  \
# math score                                                                         -0.079852
# reading score                                                                      -0.071369
# writing score                                                                      -0.097326
# total score                                                                        -0.087247
# average                                                                            -0.087247
# gender_female                                                                      -0.008990
# gender_male                                                                         0.008990
# race/ethnicity_group A                                                              0.073921
# race/ethnicity_group B                                                              0.026531
# race/ethnicity_group C                                                             -0.045339
# race/ethnicity_group D                                                              0.018402
# race/ethnicity_group E                                                             -0.053075
# parental level of education_associate's degree                                     -0.249426
# parental level of education_bachelor's degree                                      -0.170790
# parental level of education_high school                                            -0.230545
# parental level of education_master's degree                                        -0.116919
# parental level of education_some college                                           -0.252312
# parental level of education_some high school                                        1.000000
# lunch_free/reduced                                                                 -0.013874
# lunch_standard                                                                      0.013874
# test preparation course_completed                                                   0.070289
# test preparation course_none                                                       -0.070289
#
#                                                 lunch_free/reduced  \
# math score                                               -0.350877
# reading score                                            -0.229560
# writing score                                            -0.245769
# total score                                              -0.290064
# average                                                  -0.290064
# gender_female                                             0.021372
# gender_male                                              -0.021372
# race/ethnicity_group A                                    0.032329
# race/ethnicity_group B                                    0.008257
# race/ethnicity_group C                                    0.003385
# race/ethnicity_group D                                    0.009458
# race/ethnicity_group E                                   -0.052398
# parental level of education_associate's degree           -0.009102
# parental level of education_bachelor's degree             0.013668
# parental level of education_high school                   0.002211
# parental level of education_master's degree               0.027095
# parental level of education_some college                 -0.006146
# parental level of education_some high school             -0.013874
# lunch_free/reduced                                        1.000000
# lunch_standard                                           -1.000000
# test preparation course_completed                         0.017044
# test preparation course_none                             -0.017044
#
#                                                 lunch_standard  \
# math score                                            0.350877
# reading score                                         0.229560
# writing score                                         0.245769
# total score                                           0.290064
# average                                               0.290064
# gender_female                                        -0.021372
# gender_male                                           0.021372
# race/ethnicity_group A                               -0.032329
# race/ethnicity_group B                               -0.008257
# race/ethnicity_group C                               -0.003385
# race/ethnicity_group D                               -0.009458
# race/ethnicity_group E                                0.052398
# parental level of education_associate's degree        0.009102
# parental level of education_bachelor's degree        -0.013668
# parental level of education_high school              -0.002211
# parental level of education_master's degree          -0.027095
# parental level of education_some college              0.006146
# parental level of education_some high school          0.013874
# lunch_free/reduced                                   -1.000000
# lunch_standard                                        1.000000
# test preparation course_completed                    -0.017044
# test preparation course_none                          0.017044
#
#                                                 test preparation course_completed  \
# math score                                                               0.177702
# reading score                                                            0.241780
# writing score                                                            0.312946
# total score                                                              0.256710
# average                                                                  0.256710
# gender_female                                                           -0.006028
# gender_male                                                              0.006028
# race/ethnicity_group A                                                  -0.006315
# race/ethnicity_group B                                                  -0.000106
# race/ethnicity_group C                                                   0.012522
# race/ethnicity_group D                                                  -0.055956
# race/ethnicity_group E                                                   0.059393
# parental level of education_associate's degree                           0.012668
# parental level of education_bachelor's degree                            0.024285
# parental level of education_high school                                 -0.074446
# parental level of education_master's degree                             -0.009933
# parental level of education_some college                                -0.019490
# parental level of education_some high school                             0.070289
# lunch_free/reduced                                                       0.017044
# lunch_standard                                                          -0.017044
# test preparation course_completed                                        1.000000
# test preparation course_none                                            -1.000000
#
#                                                 test preparation course_none
# math score                                                         -0.177702
# reading score                                                      -0.241780
# writing score                                                      -0.312946
# total score                                                        -0.256710
# average                                                            -0.256710
# gender_female                                                       0.006028
# gender_male                                                        -0.006028
# race/ethnicity_group A                                              0.006315
# race/ethnicity_group B                                              0.000106
# race/ethnicity_group C                                             -0.012522
# race/ethnicity_group D                                              0.055956
# race/ethnicity_group E                                             -0.059393
# parental level of education_associate's degree                     -0.012668
# parental level of education_bachelor's degree                      -0.024285
# parental level of education_high school                             0.074446
# parental level of education_master's degree                         0.009933
# parental level of education_some college                            0.019490
# parental level of education_some high school                       -0.070289
# lunch_free/reduced                                                 -0.017044
# lunch_standard                                                      0.017044
# test preparation course_completed                                  -1.000000
# test preparation course_none                                        1.000000
#
# [22 rows x 22 columns]

# %%
num_data = ['math score','reading score','writing score']

# %%
sns.pairplot(df.iloc[:, 4:8])

# %% [markdown]
# #### Insights
# - All of the pairplots seems to have a linear relationship with the other variable. To clarify that we'll plot the correlation map.

# %%
num_features=[col for col in df.columns if df[col].dtype!='O']
num_df = df[num_features]

# %% [markdown]
# #### 2.2  Shapiro Wick Test
# * **The Shapiro-Wilk test is a way to tell if a random sample comes from a normal distribution.**
#
# - Ho : Data is normally distributed
# - H1 : Data is not normally distributed

# %%
from scipy.stats import shapiro

shapiro_wick_test = []

for column in num_features:
    
    dataToTest = num_df[column]
    
    stat,p = shapiro(dataToTest)
    
    if p > 0.05:
        
        shapiro_wick_test.append("Normally Distributed")
        
    else:
        shapiro_wick_test.append("Not Normally Distributed")
        
result = pd.DataFrame(data=[num_features, shapiro_wick_test]).T
result.columns = ['Column Name', 'Shapiro Hypothesis Result']
result
# Out:
#      Column Name Shapiro Hypothesis Result
# 0     math score  Not Normally Distributed
# 1  reading score  Not Normally Distributed
# 2  writing score  Not Normally Distributed
# 3    total score  Not Normally Distributed
# 4        average  Not Normally Distributed

# %% [markdown]
# #### 2.3 K^2 Normality Test
# * **Test aims to establish whether or not the given sample comes from a normally distributed population. Test is based on transformations of the sample kurtosis and skewness**
#
# - Ho : Data is normally distributed
# - H1 : Data is not normally distributed

# %%
from scipy.stats import normaltest

normaltest_test = []

for column in num_features:
    
    dataToTest = num_df[column]
    
    stat,p = normaltest(dataToTest)
    
    if p > 0.05:
        normaltest_test.append("Normally Distributed")
        
    else:
        normaltest_test.append("Not Normally Distributed")
        
result = pd.DataFrame(data=[num_features, normaltest_test]).T
result.columns = ['Column Name', 'normaltest Hypothesis Result']
result
# Out:
#      Column Name normaltest Hypothesis Result
# 0     math score     Not Normally Distributed
# 1  reading score     Not Normally Distributed
# 2  writing score     Not Normally Distributed
# 3    total score     Not Normally Distributed
# 4        average     Not Normally Distributed

# %% [markdown]
# #### 2.4 Spearmanr Test
#
# * **Spearman Rank Correlation, which is used to measure the correlation between two ranked variables**
# * **Whereas The Pearson correlation coefficient is computed using raw data values**
# * **Unlike the Pearson correlation, the Spearman correlation does not assume that both datasets are normally distributed.**
# * **Spearman rank correlation is closely related to the Pearson correlation, and both are a bounded value, from -1 to 1 denoting a correlation between two variables.**
# - Ho : Independent Samples
# - H1 : Dependent Samples

# %%
plt.rcParams["figure.figsize"] = (15,6)
plt.subplot(1, 3, 1)
plt.plot(num_df['math score'],num_df['reading score'])
plt.subplot(1, 3, 2)
plt.plot(num_df['writing score'],num_df['reading score'])
plt.subplot(1, 3, 3)
plt.plot(num_df['math score'],num_df['writing score'])
plt.show()

# %% [markdown]
# #### Insight
# - We can observe linear relationship amoung two varibales.
# - lets prove it hypothetically too using spearman Rank and Pearson Correlation Tests.

# %%
from scipy.stats import spearmanr
from scipy.stats import pearsonr

def test_correlation(test_name,column1, column2):
    column1_to_test = num_df[column1]
    column2_to_test = num_df[column2]
    stat,p = test_name(column1_to_test , column2_to_test)
    d =dict()
    d['col1'] = column1
    d['col2'] = column2
    if p> 0.05:
        test_results.append("Independent Samples")
    else:
        test_results.append("Dependent Samples")
    columns_combination.append(d)

# %%
columns_combination = []
test_results = []
test_correlation(spearmanr,'math score','reading score')

# %%
test_correlation(spearmanr,'writing score','reading score')

# %%
test_correlation(spearmanr,'math score','writing score')

# %%
df_spearmanr = pd.DataFrame(columns_combination,test_results)
df_spearmanr
# Out:
#                             col1           col2
# Dependent Samples     math score  reading score
# Dependent Samples  writing score  reading score
# Dependent Samples     math score  writing score

# %% [markdown]
# ####  2.5 pearsonr Test
# - Ho : Independent Samples
# - H1 : Dependent Samples

# %%
columns_combination = []
test_results = []
test_correlation(pearsonr,'math score','reading score')

# %%
test_correlation(pearsonr,'writing score','reading score')

# %%
test_correlation(pearsonr,'math score','writing score')

# %%
df_pearsonr = pd.DataFrame(columns_combination,test_results)
df_pearsonr
# Out:
#                             col1           col2
# Dependent Samples     math score  reading score
# Dependent Samples  writing score  reading score
# Dependent Samples     math score  writing score

# %% [markdown]
# #### Result
# - At 5% level of significance
# - From above two tests of Pearsonr and Spearmanr ,
# - since all the three p-values are more than 0.05.
# - Inference: The scores have a correlation between them.

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %% [markdown]
# #### 2.6 Chi-squared test
# * **Tests whether two categorical fetaures are dependent or Not.**
# * Here we will test correlation of Categorical columns with Target column i.e average
# * Assumptions-
#  - All are Independent observation
#  - Size of each box of contingency table > 25

# %%
from scipy.stats import chi2_contingency
chi2_squared_test = []
for feature in categorical_features:
    stat, p , dof, expected = chi2_contingency(pd.crosstab(df['average'], df[feature]))
    if p> 0.05:
        chi2_squared_test.append("Independent Categories")
    else:
        chi2_squared_test.append("Dependent Categories")
result = pd.DataFrame(data=[categorical_features, chi2_squared_test]).T
result.columns = ['Column', 'Hypothesis Result']
result
# Out:
#                         Column       Hypothesis Result
# 0                       gender  Independent Categories
# 1               race/ethnicity  Independent Categories
# 2  parental level of education  Independent Categories
# 3                        lunch    Dependent Categories
# 4      test preparation course    Dependent Categories

# %% [markdown]
# **Insights**
# * Here our output is dependent on Lunch & Test preparation course columns

# %% [markdown]
# #### 2.7 Levene's Test
# * **Equality of variance test**
#
# - Ho : Female and male have equal variance
# - H1 : Female and male do not have equal variance

# %%
math_var = scipy.stats.levene(df[df['gender']=='female']['math score'],
                  df[df['gender']=='male']['math score'], center = 'mean')
reading_var = scipy.stats.levene(df[df['gender']=='female']['reading score'],
                  df[df['gender']=='male']['reading score'], center = 'mean')
writing_var = scipy.stats.levene(df[df['gender']=='female']['writing score'],
                  df[df['gender']=='male']['writing score'], center = 'mean')
print("Test Statistic and p-value for math  is", math_var)
print('\n')
print("Test Statistic and p-value for writing is", writing_var)
print('\n')
print("Test Statistic and p-value for reading is", reading_var)
# Out:
# Test Statistic and p-value for math  is LeveneResult(statistic=0.39659058260357727, pvalue=0.5289994390328784)
#
#
# Test Statistic and p-value for writing is LeveneResult(statistic=0.029036281877215228, pvalue=0.8647298283415281)
#
#
# Test Statistic and p-value for reading is LeveneResult(statistic=0.016652697287322132, pvalue=0.8973477814233404)

# %% [markdown]
# #### Result
# - Conclusion : Since, at 5% level of significance, P(calculated) > P(0.05).
# - Therefore we will accept the null hypothesis
# - Inference : All the scores have equal variance with respect to gender.

# %% [markdown]
# #### 2.8 Checking Correlation using Heatmaps

# %%
 # Relationship analysis
sns.heatmap(df_numeric.corr(),annot=True,cmap='icefire',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(16,10)
plt.title('Correlation between math, reading and writing scores',color='black',size=25)
plt.show()

# %% [markdown]
# #### Insights
# - Total_score is highly correlated with individual score.
# - Reading score is also highly correlated with writing score which means students who reads well can also writes well.
# - Math_score doesnt have much high correlation so it is not neccessary that if a student performs well in maths has to perform well in other aspects or vice-versa
# - Total_score and average are highy correlated , hence we can delete one amoung them.

# %% [markdown]
# ###  3 . Checking for Normal Distribution using Transformations
# - Q-Q plot (to check if data is normally distributed or not)

# %%
# density plot using seaborn library
fig, axs = plt.subplots(2, 2, figsize=(15, 7))

sns.kdeplot(df['math score'],shade=True,label='Maths',color='gold',ax=axs[0, 0],alpha=0.5)
sns.kdeplot(df['reading score'],shade=True,label='Reading',color='indigo',ax=axs[0, 1],alpha=0.5)
sns.kdeplot(df['writing score'],shade=True,label='Writing',color='pink',ax=axs[1, 0],alpha=0.5)
sns.kdeplot(df['average'],shade=True,label='Total',color='slateblue',ax=axs[1, 1],alpha=0.5)
plt.show()

# %% [markdown]
# #### 3.1 Log Transform

# %%
plots(df,'average',np.log(df['average']))
print("Skewness value", np.log(df['average']).skew())
# Out:
# Skewness value -1.5373448376786043

# %% [markdown]
# #### Insights
# - A negatively skewed (also known as left-skewed) distribution is a type of distribution in which more values are concentrated on the right side (tail) of the distribution graph while the left tail of the distribution graph is longer.

# %% [markdown]
# #### 3.2. Square Root Transform

# %%
plots(df,'average',np.sqrt(df['average']))
print("Skewness value", np.sqrt(df['average']).skew())
# Out:
# Skewness value -0.7534310044571916

# %% [markdown]
# #### 3.3 Box-Cox Transform
# - Assumption -
#  * your data must be positive

# %% [markdown]
# # here i am ploting the distribution and qq plot

# %%
plot_qq_plot('math score')

# %%
plot_qq_plot('reading score')

# %%
plot_qq_plot('writing score')

# %%
plot_qq_plot('average')

# %% [markdown]
# #### Insights
# -  For range -2 to 2 avg_score & math score follows normal distribution, but for values less than -2 and for values greater than 2 it doesn't follow normal distribution

# %%
import statsmodels.api as sm # to build the Q-Q graph
# Create three subplots
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3,figsize=(15, 7)) 


sm.qqplot(df['math score'], markerfacecolor = "green", markeredgecolor = "green", line='45',  fit = True, ax=ax1)
ax1.set_title("Math Scores")

sm.qqplot(df['reading score'], markerfacecolor = "orange", markeredgecolor = "orange", line='45', fit = True, ax=ax2)
ax2.set_title("Reading Scores")

sm.qqplot(df['writing score'], markerfacecolor = "blue", markeredgecolor = "blue", line='45', fit = True, ax=ax3)
ax3.set_title("Writing Scores")

# Set the global title
plt.suptitle("Normality check of students scores using Q-Q chart")

plt.show()

# %% [markdown]
#  #### Insights
#   - There exists correlation between students scores and the normal distribution line. This means that our data is very close to Gaussian!
